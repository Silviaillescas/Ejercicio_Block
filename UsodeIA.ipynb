# %% [markdown]
# ## Prompt utilizado

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Nota
#
# Para el desarrollo de este laboratorio utilicé herramientas de IA (ChatGPT) como apoyo y guía durante la implementación. La herramienta me ayudó a resolver dudas, entender mejor algunos conceptos de criptografía y corregir ciertos errores que aparecieron durante la programación.
